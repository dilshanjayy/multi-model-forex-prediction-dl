# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath("../.."))

from src.preprocessing.feature_engineering import create_labels, engineer_technical_features

df_pro = pd.read_csv("../../data/processed_market/processed_EURUSD_H1_20200101_20260131.csv")
df_raw = pd.read_csv("../../data/raw_market/EURUSD_H1_20200101_20260131.csv")

# %%
df_pro = create_labels(df_pro, future_periods=5)

print(df_pro['Target'].value_counts(normalize=True) * 100)
# Out:
# Target
# 0    35.00106
# 2    34.99841
# 1    30.00053
# Name: proportion, dtype: float64
