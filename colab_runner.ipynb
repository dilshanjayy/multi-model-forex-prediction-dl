# %% [markdown]
# # Forex Transformer Optimization on Colab
# This notebook mounts your Google Drive, installs dependencies, and runs the Optuna optimization for your Transformer model using a free NVIDIA GPU.

# %% [markdown]
# **Update the path below** to point to where you uploaded your project folder in Google Drive.

# %%
# %cd /content/drive/MyDrive/multi-model-forex-prediction-dl

# %%
# %pip install -r requirements_colab.txt

# %%
# !python main.py optimize --config configs/baseline_transformer.yaml --trials 50

# %% [markdown]
# Once the optimization is complete, the `optimized_baseline_transformer.yaml` will be saved directly to your Google Drive! You can then download it and run the backtest locally on your laptop.
